# %%
from transformers import AutoTokenizer, AutoModel, TFAutoModel, AutoModelForSequenceClassification, TFAutoModelForSequenceClassification, BertModel, BertForSequenceClassification, BertTokenizer
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Concatenate, GlobalAveragePooling1D
import torch
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics.pairwise import cosine_similarity
from torchsummary import summary
import tensorflow as tf
import datasets
import numpy as np
import pandas as pd
from scipy.special import softmax
from sklearn import metrics
from sklearn.utils.class_weight import compute_class_weight
from time import time
import gc

# %%
class Sample:
    pass

class Factual_info:
    def __init__(self,text):
         self.text = text
         self.sent = [0,0,0]
         self.sent_pred = 0
         self.off = 0
         self.off_pred = 0
         self.hate_peace = 0
         self.peace_pred = 0
         self.hate_gen = 0
         self.gen_pred = 0
         self.hate_hateBERT = 0
         self.hateBERT_pred = 0
         self.sem_emb = 0
    
    def print_info(self):
        print("Text:")
        print(self.text)
        print()
        print("Sentiment")
        print("Negative:",self.sent[0])
        print("Neutral:",self.sent[1])
        print("Positive:",self.sent[2])
        print()
        print("Offense:",self.off)
        print()
        print("Hate of PEACE:",self.hate_peace)
        print()
        print("Hate of the general module:",self.hate_gen)
        print()
        print("Hate of HateBERT:",self.hate_hateBERT)
        
class Metrics:
    def __init__(self):
        self.dist_sent = 0
        self.dist_off = 0
        self.same_sent = 0
        self.distinct_off = 0
        self.off_improvement = 0
        self.sem_sim = 0
    
    def print_metrics(self):
        print("Metrics")
        print("Sentiment distance:",self.dist_sent)
        print("Offense distance:",self.dist_off)
        print()
        print("Same Sentiment:",self.same_sent)
        print("Distinct Offense:",self.distinct_off)
        print("Offense improvement:",self.off_improvement)
        print()
        print("Sentence similarity:",self.sem_sim)

# %% [markdown]
# # Causal modules

# %%
#roBERTa models
sent_MOD = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
aggr_MOD = f"cardiffnlp/twitter-roberta-base-offensive"

#Load tokenizer and models
tokenizer = AutoTokenizer.from_pretrained(sent_MOD)
sent_class_mod = AutoModelForSequenceClassification.from_pretrained(sent_MOD)
aggr_class_mod = AutoModelForSequenceClassification.from_pretrained(aggr_MOD)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def Compute_Caus_Outs(tokenizer,sent_mod,aggr_mod,texts,batch_size):
  # Split texts into batches
  batches = [texts[i:i + batch_size] for i in range(0, len(texts), batch_size)]
  batch_out_1 = []
  batch_out_2 = []
  for batch in batches:
      encoded_inputs = tokenizer(batch,padding=True,return_tensors='pt')
      # Compute the outputs of the modules as numpy arrays.
      emb_1 = sent_mod(**encoded_inputs)[0]
      scores_1 = []
      for i in range(emb_1.shape[0]):
            scores_1.append(softmax(emb_1[i].detach().numpy()))
      scores_1 = np.array(scores_1)
      batch_out_1.append(scores_1)  

      emb_2 = aggr_mod(**encoded_inputs)[0]
      scores_2 = []
      for i in range(emb_2.shape[0]):
            scores_2.append(softmax(emb_2[i].detach().numpy()))
      scores_2 = np.array(scores_2)
      batch_out_2.append(scores_2)
    
      encoded_inputs = None
      emb_1 = None
      emb_2 = None
      gc.collect() 
    
  outs_sent = np.concatenate(batch_out_1,axis=0)
  outs_aggr = np.concatenate(batch_out_2,axis=0)  

  return outs_sent,outs_aggr

# %% [markdown]
# ## Loading the factuals

# %%
def get_texts(df):
    np_array = df["text"].to_numpy()
    texts = []
    for i in range(len(np_array)):
        texts.append(np_array[i])
    return texts

# %%
df_factuals = pd.read_csv('data/factuals.tsv',sep='\t')
factuals = get_texts(df_factuals)
labels_factuals = df_factuals["label"].to_numpy()

# %%
samples = []
for i in range(len(factuals)):
    samples.append(Sample())
    samples[i].factual = Factual_info(factuals[i])

# %% [markdown]
# ## Loading the sentiment and offense of the factuals

# %%
class_fact_sent = np.load('outs/counterfactuals/class_fact_sent.npy')
class_fact_off = np.load('outs/counterfactuals/class_fact_off.npy')
factual_sent = np.load('outs/counterfactuals/factual_sent.npy')
factual_off = np.load('outs/counterfactuals/factual_off.npy')

# %%
for i in range(len(samples)):
    samples[i].factual.sent = class_fact_sent[i]
    samples[i].factual.sent_pred = factual_sent[i]
    samples[i].factual.off = class_fact_off[i][1]
    samples[i].factual.off_pred = factual_off[i]

# %% [markdown]
# ## Loading the counterfactuals

# %%
n_cf = 5
df_cf_off = pd.read_csv('data/cf_off.tsv',sep='\t')
cf_off = get_texts(df_cf_off)

# %%
metrics_cf_off = []
i = 0
for j in range(0,len(cf_off),n_cf):
    cf = []
    met = []
    for k in range(n_cf):
        cf.append(Factual_info(cf_off[j+k]))
        met.append(Metrics())
    samples[i].cf_off = cf.copy()
    metrics_cf_off.append(met.copy())
    i+=1

# %% [markdown]
# ## Getting the counterfactuals output (If they are already saved you can skip this step)

# %%
def print_causal_result(text,sent,aggr):
    print("Text:")
    print(text)
    print()
    print("Sentiment")
    print("Negative:",sent[0])
    print("Neutral:",sent[1])
    print("Positive:",sent[2])
    print()
    print("Aggression")
    print("Not offensive:",aggr[0])
    print("Offensive:",aggr[1])
    
def print_causal_results(texts,sents,aggrs):
    for i in range(len(texts)):
        print_causal_result(texts[i],sents[i],aggrs[i])
        print()
        print()

# %%
batch_size = 32

cf_pred_sent = []
cf_pred_off = []
t = time()
class_cf_sent,class_cf_off = Compute_Caus_Outs(tokenizer,sent_class_mod,aggr_class_mod,cf_off,batch_size)
print("Elapsed time:",time()-t)
for i in range(len(cf_off)):
        cf_pred_sent.append(class_cf_sent[i].argmax())
        cf_pred_off.append(class_cf_off[i].argmax())    
#print_causal_results(counterfactuals,class_cfact_sent,class_cfact_aggr)
# Out:
# Elapsed time: 1952.1373901367188

# %%
np.save('outs/counterfactuals/class_cf_sent.npy',class_cf_sent)
np.save('outs/counterfactuals/class_cf_off.npy',class_cf_off)
np.save('outs/counterfactuals/cf_pred_sent.npy',cf_pred_sent)
np.save('outs/counterfactuals/cf_pred_off.npy',cf_pred_off)

# %% [markdown]
# ## Loading the counterfactuals output

# %%
class_cf_sent = np.load('outs/counterfactuals/class_cf_sent.npy')
class_cf_off = np.load('outs/counterfactuals/class_cf_off.npy')
cf_pred_sent = np.load('outs/counterfactuals/cf_pred_sent.npy')
cf_pred_off = np.load('outs/counterfactuals/cf_pred_off.npy')

# %%
i = 0
for j in range(0,len(cf_off),n_cf):
    for k in range(n_cf):
        samples[i].cf_off[k].sent = class_cf_sent[j+k]
        samples[i].cf_off[k].sent_pred = cf_pred_sent[j+k]
        samples[i].cf_off[k].off = class_cf_off[j+k][1]
        samples[i].cf_off[k].off_pred = cf_pred_off[j+k]
    i+=1

# %% [markdown]
# # Hate models

# %% [markdown]
# ## Load train data embeddings

# %%
frenk_sent_train = np.load('outs/frenk/sent_train_outs.npy')
frenk_aggr_train = np.load('outs/frenk/aggr_train_outs.npy')
frenk_gen_train = np.load('outs/frenk/gen_train_outs.npy')

# %%
# ghc_sent_train = np.load('outs/ghc/sent_train_outs.npy')
# ghc_aggr_train = np.load('outs/ghc/aggr_train_outs.npy')
# ghc_gen_train = np.load('outs/ghc/gen_train_outs.npy')

# %%
try_sent_train = np.load('outs/try/sent_train_outs.npy')
try_aggr_train = np.load('outs/try/aggr_train_outs.npy')
try_gen_train = np.load('outs/try/gen_train_outs.npy')

# %%
sent_train = np.concatenate([frenk_sent_train,try_sent_train],axis=0)
aggr_train = np.concatenate([frenk_aggr_train,try_aggr_train],axis=0)
gen_train = np.concatenate([frenk_gen_train,try_gen_train],axis=0)

# %%
conc_train = np.concatenate([sent_train,aggr_train,gen_train],axis=1)

# %% [markdown]
# ## Load train data labels

# %%
#FRENK dataset
df_train = pd.read_csv('data/frenk_train.tsv',sep='\t')
frenk_label_train = df_train["label"].to_numpy()

# %%
# def get_hate_labels(labels):
#    hate_labels = np.zeros(len(labels))
#    for i in range(len(labels)):
#        if labels[i].any():
#            hate_labels[i] = 1
#    return hate_labels

# %%
# #Gab dataset
# df_train = pd.read_csv('data/ghc_train_8404.tsv',sep='\t')
# labels = df_train[["hd","cv"]].to_numpy()
# ghc_label_train = get_hate_labels(labels)
# ghc_label_train = ghc_label_train

# %%
#Twi-Red-You dataset
df_train = pd.read_csv('data/try_train_8404.tsv',sep='\t')
try_label_train = df_train['hate'].to_numpy()

# %%
label_train = np.concatenate([frenk_label_train,try_label_train])

# %%
c_weights = compute_class_weight('balanced', classes=np.unique(label_train), y=label_train)
c_weights = {0:c_weights[0], 1:c_weights[1]}

# %% [markdown]
# ## Peace modules

# %%
#roBERTa models
sent_MOD = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
aggr_MOD = f"cardiffnlp/twitter-roberta-base-offensive"
gen_MOD = f"roberta-base"

#Load tokenizer and models
tokenizer = AutoTokenizer.from_pretrained(sent_MOD)
sent_mod = TFAutoModel.from_pretrained(sent_MOD)
aggr_mod = TFAutoModel.from_pretrained(aggr_MOD)
gen_mod = TFAutoModel.from_pretrained(gen_MOD)

batch_size = 32
# Out:
# All model checkpoint layers were used when initializing TFRobertaModel.
#
# All the layers of TFRobertaModel were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Some layers from the model checkpoint at cardiffnlp/twitter-roberta-base-offensive were not used when initializing TFRobertaModel: ['classifier']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-offensive.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.dense.bias', 'roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def Compute_Embeddings(tokenizer,sent_mod,aggr_mod,gen_mod,texts,batch_size):
  # Split texts into batches
  batches = [texts[i:i + batch_size] for i in range(0, len(texts), batch_size)]
  batch_out_1 = []
  batch_out_2 = []
  batch_out_3 = []
  for batch in batches:
      encoded_inputs = tokenizer(batch,padding=True,return_tensors='tf')
      # Compute the outputs of the modules as numpy arrays.
      emb_1 = sent_mod(encoded_inputs)[0]
      pool_1 = GlobalAveragePooling1D()(emb_1).numpy()
      batch_out_1.append(pool_1)

      emb_2 = aggr_mod(encoded_inputs)[0]
      pool_2 = GlobalAveragePooling1D()(emb_2).numpy()
      batch_out_2.append(pool_2)

      emb_3 = gen_mod(encoded_inputs)[0]
      pool_3 = GlobalAveragePooling1D()(emb_3).numpy()
      batch_out_3.append(pool_3)
    
      encoded_inputs = None
      emb_1 = None
      emb_2 = None
      emb_3 = None
      gc.collect() 
    
  outs_1 = np.concatenate(batch_out_1,axis=0)
  outs_2 = np.concatenate(batch_out_2,axis=0)
  outs_3 = np.concatenate(batch_out_3,axis=0)  

  return outs_1,outs_2,outs_3

# %% [markdown]
# ## Getting the embeddings of the factuals and counterfactuals (If they are already saved you can skip this step)

# %%
###Factuals
out_sent,out_aggr,out_gen = Compute_Embeddings(tokenizer,sent_mod,aggr_mod,gen_mod,factuals,batch_size)

np.save('outs/counterfactuals/sent_fact_outs.npy',out_sent)
np.save('outs/counterfactuals/aggr_fact_outs.npy',out_aggr)
np.save('outs/counterfactuals/gen_fact_outs.npy',out_gen)

# %%
###Counterfactuals
out_sent,out_aggr,out_gen = Compute_Embeddings(tokenizer,sent_mod,aggr_mod,gen_mod,cf_off,batch_size)

np.save('outs/counterfactuals/sent_cf_off_outs.npy',out_sent)
np.save('outs/counterfactuals/aggr_cf_off_outs.npy',out_aggr)
np.save('outs/counterfactuals/gen_cf_off_outs.npy',out_gen)

# %% [markdown]
# ## Loading the embeddings of the factuals and counterfactuals

# %%
###Factuals
sent_fact_outs = np.load('outs/counterfactuals/sent_fact_outs.npy')
aggr_fact_outs = np.load('outs/counterfactuals/aggr_fact_outs.npy')
gen_fact_outs = np.load('outs/counterfactuals/gen_fact_outs.npy')

# %%
###Counterfactuals
sent_cf_off_outs = np.load('outs/counterfactuals/sent_cf_off_outs.npy')
aggr_cf_off_outs = np.load('outs/counterfactuals/aggr_cf_off_outs.npy')
gen_cf_off_outs = np.load('outs/counterfactuals/gen_cf_off_outs.npy')

# %%
print((sent_cf_off_outs.shape[1]+gen_cf_off_outs.shape[1])+(sent_fact_outs.shape[1]+gen_fact_outs.shape[1]))
print(sent_fact_outs.shape,gen_fact_outs.shape)
print(sent_cf_off_outs.shape,gen_cf_off_outs.shape)
# Out:
# 3072
# (3127, 768) (3127, 768)
# (15635, 768) (15635, 768)

# %% [markdown]
# ## Getting the output of the Hate models

# %%
def print_hate_result(text,hate):
    print("Text:")
    print(text)
    print("Hate prob.:",hate[0])
    
def print_hate_results(texts,hates):
    for i in range(len(texts)):
        print_hate_result(texts[i],hates[i])
        print()
        print()

# %%
conc_fact = np.concatenate([sent_fact_outs,aggr_fact_outs,gen_fact_outs],axis=1)
conc_cf_off = np.concatenate([sent_cf_off_outs,aggr_cf_off_outs,gen_cf_off_outs],axis=1)

# %%
n_avg = 20

# %% [markdown]
# ### PEACE model

# %%
f_hate = []
cf_off_hate = []
for i in range(n_avg):
    hate_model = Sequential([
          Flatten(),
          Dense(128, activation='relu'),
          Dense(128, activation='relu'),
          Dense(1, activation='sigmoid')
      ])
    hate_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    hate_model.fit(conc_train, label_train, class_weight=c_weights, epochs=10, batch_size=32)
    f_hate.append(hate_model.predict(conc_fact))
    cf_off_hate.append(hate_model.predict(conc_cf_off))
f_hate = np.mean(f_hate,axis=0)
cf_off_hate = np.mean(cf_off_hate,axis=0)
# Out:
# Epoch 1/10
# 526/526 [==============================] - 3s 3ms/step - loss: 0.5490 - accuracy: 0.7007
# Epoch 2/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5168 - accuracy: 0.7204
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5047 - accuracy: 0.7258
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4928 - accuracy: 0.7351
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4791 - accuracy: 0.7438
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4720 - accuracy: 0.7438
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4593 - accuracy: 0.7540
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4478 - accuracy: 0.7590
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4400 - accuracy: 0.7622
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4242 - accuracy: 0.7719
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5492 - accuracy: 0.7067
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5182 - accuracy: 0.7215
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5030 - accuracy: 0.7304
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4923 - accuracy: 0.7392
# Epoch 5/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4821 - accuracy: 0.7429
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4653 - accuracy: 0.7530
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4531 - accuracy: 0.7620
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4429 - accuracy: 0.7648
# Epoch 9/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4278 - accuracy: 0.7783
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4166 - accuracy: 0.7818
# 98/98 [==============================] - 0s 979us/step
# 489/489 [==============================] - 0s 899us/step
# Epoch 1/10
# 526/526 [==============================] - 3s 2ms/step - loss: 0.5461 - accuracy: 0.7015
# Epoch 2/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5171 - accuracy: 0.7228
# Epoch 3/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5010 - accuracy: 0.7322
# Epoch 4/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4904 - accuracy: 0.7383
# Epoch 5/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4820 - accuracy: 0.7412
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4690 - accuracy: 0.7489
# Epoch 7/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4536 - accuracy: 0.7589
# Epoch 8/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4380 - accuracy: 0.7640
# Epoch 9/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4237 - accuracy: 0.7757
# Epoch 10/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4124 - accuracy: 0.7819
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5455 - accuracy: 0.7016
# Epoch 2/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5213 - accuracy: 0.7157
# Epoch 3/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5044 - accuracy: 0.7259
# Epoch 4/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4968 - accuracy: 0.7324
# Epoch 5/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4840 - accuracy: 0.7376
# Epoch 6/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4724 - accuracy: 0.7457
# Epoch 7/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4630 - accuracy: 0.7494
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4522 - accuracy: 0.7585
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4389 - accuracy: 0.7689
# Epoch 10/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4264 - accuracy: 0.7741
# 98/98 [==============================] - 0s 898us/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7072
# Epoch 2/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5178 - accuracy: 0.7241
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5048 - accuracy: 0.7307
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4933 - accuracy: 0.7403
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4822 - accuracy: 0.7435
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4715 - accuracy: 0.7492
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4596 - accuracy: 0.7559
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4455 - accuracy: 0.7610
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4349 - accuracy: 0.7715
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4199 - accuracy: 0
10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4450 - accuracy: 0.7658
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4322 - accuracy: 0.7682
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4184 - accuracy: 0.7799
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7089
# Epoch 2/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5151 - accuracy: 0.7271
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5043 - accuracy: 0.7322
# Epoch 4/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4923 - accuracy: 0.7357
# Epoch 5/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4807 - accuracy: 0.7409
# Epoch 6/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4679 - accuracy: 0.7483
# Epoch 7/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4599 - accuracy: 0.7571
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4497 - accuracy: 0.7577
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4345 - accuracy: 0.7639
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4247 - accuracy: 0.7699
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7068
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5170 - accuracy: 0.7186
# Epoch 3/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5033 - accuracy: 0.7254
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4897 - accuracy: 0.7374
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4764 - accuracy: 0.7406
# Epoch 6/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4689 - accuracy: 0.7441
# Epoch 7/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4556 - accuracy: 0.7523
# Epoch 8/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4422 - accuracy: 0.7596
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4316 - accuracy: 0.7686
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4208 - accuracy: 0.7753
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.6993
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5199 - accuracy: 0.7161
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5051 - accuracy: 0.7257
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4926 - accuracy: 0.7376
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4786 - accuracy: 0.7445
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4705 - accuracy: 0.7469
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4506 - accuracy: 0.7571
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4429 - accuracy: 0.7649
# Epoch 9/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4288 - accuracy: 0.7721
# Epoch 10/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4137 - accuracy: 0.7803
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 0s 980us/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7094
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5194 - accuracy: 0.7201
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5023 - accuracy: 0.7336
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4907 - accuracy: 0.7386
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4817 - accuracy: 0.7412
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4692 - accuracy: 0.7480
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4574 - accuracy: 0.7554
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4407 - accuracy: 0.7639
# Epoch 9/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4270 - accuracy: 0.7739
# Epoch 10/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4175 - accuracy: 0.7792
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 0s 935us/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7053
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5173 - accuracy: 0.7252
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5035 - accuracy: 0.7335
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4908 - accuracy: 0.7377
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4798 - accuracy: 0.7477
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4677 - accuracy: 0.7499
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4559 - accuracy: 0.7570
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4452 - accuracy: 0.7642
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4335 - accuracy: 0.7687
# Epoch 10/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4171 - accuracy: 0.7769
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7112
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5153 - accuracy: 0.7238
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5020 - accuracy: 0.7354
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4935 - accuracy: 0.7357
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4779 - accuracy: 0.7467
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4680 - accuracy: 0.7493
# Epoch 7/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4545 - accuracy: 0.7590
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4422 - accuracy: 0.7650
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4287 - accuracy: 0.7694
# Epoch 10/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4170 - accuracy: 0.7799
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step

# %%
print(f_hate)
# Out:
# [[9.3064315e-08]
#  [1.7472804e-01]
#  [5.0119966e-01]
#  ...
#  [7.1946398e-04]
#  [5.0764048e-01]
#  [9.0138651e-03]]

# %%
i = 0
for j in range(0,len(cf_off),n_cf):
    samples[i].factual.hate_peace = f_hate[i][0]
    samples[i].factual.peace_pred = 1 if f_hate[i][0] > 0.5 else 0
    for k in range(n_cf):
        samples[i].cf_off[k].hate_peace = cf_off_hate[j+k][0]
        samples[i].cf_off[k].peace_pred = 1 if cf_off_hate[j+k][0] > 0.5 else 0
    i+=1
#print_hate_results(factuals,f_hate)

# %% [markdown]
# ### General model

# %%
f_hate = []
cf_off_hate = []
for i in range(n_avg):
    hate_model = Sequential([
          Flatten(),
          Dense(128, activation='relu'),
          Dense(128, activation='relu'),
          Dense(1, activation='sigmoid')
      ])
    hate_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5112 - accuracy: 0.7219
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4960 - accuracy: 0.7319
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4758 - accuracy: 0.7443
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4550 - accuracy: 0.7605
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4357 - accuracy: 0.7729
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.7867
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3916 - accuracy: 0.8005
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 0s 917us/step
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5875 - accuracy: 0.6691
# Epoch 2/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5434 - accuracy: 0.6975
# Epoch 3/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5270 - accuracy: 0.7081
# Epoch 4/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5126 - accuracy: 0.7186
# Epoch 5/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4911 - accuracy: 0.7395
# Epoch 6/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4755 - accuracy: 0.7420
# Epoch 7/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4550 - accuracy: 0.7592
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4361 - accuracy: 0.7722
# Epoch 9/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4097 - accuracy: 0.7899
# Epoch 10/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.3861 - accuracy: 0.8047
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5829 - accuracy: 0.6784
# Epoch 2/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5442 - accuracy: 0.7007
# Epoch 3/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.5300 - accuracy: 0.7109
# Epoch 4/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5125 - accuracy: 0.7169
# Epoch 5/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4983 - accuracy: 0.7351
# Epoch 6/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4796 - accuracy: 0.7435
# Epoch 7/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4631 - accuracy: 0.7522
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4426 - accuracy: 0.7684
# Epoch 9/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4198 - accuracy: 0.7832
# Epoch 10/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.3981 - accuracy: 0.7982
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 1ms/step

# %%
i = 0
for j in range(0,len(cf_off),n_cf):
    samples[i].factual.hate_gen = f_hate[i][0]
    samples[i].factual.gen_pred = 1 if f_hate[i][0] > 0.5 else 0
    for k in range(n_cf):
        samples[i].cf_off[k].hate_gen = cf_off_hate[j+k][0]
        samples[i].cf_off[k].gen_pred = 1 if cf_off_hate[j+k][0] > 0.5 else 0
    i+=1

# %% [markdown]
# ### HateBERT

# %%
frenk_train_emb = np.load('outs/frenk/HateBERT_train_emb.npy')
#ghc_train_emb = np.load('outs/ghc/HateBERT_train_emb.npy')
try_train_emb = np.load('outs/try/HateBERT_train_emb.npy')
train_emb = np.concatenate([frenk_train_emb,try_train_emb],axis=0)

# %%
model_dir = "HateBERT_hateval"
HateBERT = BertModel.from_pretrained(
    model_dir # Use pre-trained model from its directory, change this to use a pre-trained model from bert
)
HateBERT.eval()
HateBERT_tok = BertTokenizer.from_pretrained(model_dir)

# %%
def Comp_Embed_HateBERT(tokenizer,mod,texts,batch_size):
  # Split texts into batches
  batches = [texts[i:i + batch_size] for i in range(0, len(texts), batch_size)]
  batch_out = []

  with torch.no_grad():
      for batch in batches:
          encoded_inputs = tokenizer(batch,padding=True,return_tensors='pt')
          # Compute the output of the module as a numpy array.

          emb = mod(**encoded_inputs)[0]
          tf_emb = tf.convert_to_tensor(emb.numpy())  
          pool = GlobalAveragePooling1D()(tf_emb).numpy()
          batch_out.append(pool)

          encoded_inputs = None
          tf_emb = None
          gc.collect() 
    
  outs = np.concatenate(batch_out,axis=0)
  return outs

# %% [markdown]
# #### Getting the embeddings of the factuals and counterfactuals (If they are already saved you can skip this step)

# %%
fact_HateBERT = Comp_Embed_HateBERT(HateBERT_tok,HateBERT,factuals,batch_size)
np.save('outs/counterfactuals/fact_HateBERT.npy',fact_HateBERT)

# %%
cf_off_HateBERT = Comp_Embed_HateBERT(HateBERT_tok,HateBERT,cf_off,batch_size)
np.save('outs/counterfactuals/cf_off_HateBERT.npy',cf_off_HateBERT)

# %% [markdown]
# #### Loading the embeddings of the factuals and counterfactuals

# %%
fact_HateBERT = np.load('outs/counterfactuals/fact_HateBERT.npy')
cf_off_HateBERT = np.load('outs/counterfactuals/cf_off_HateBERT.npy')

# %% [markdown]
# #### Getting the output of the HateBERT model

# %%
f_hate = []
cf_off_hate = []
for i in range(n_avg):
    classifier_HateBERT = Sequential([
          Flatten(),
          Dense(128, activation='relu'),
          Dense(128, activation='relu'),
          Dense(1, activation='sigmoid')
      ])
    classifier_HateBERT.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    classifier_HateBERT.fit(train_emb, label_train, class_weight=c_weights, epochs=10, batch_size=32)
    f_hate.append(classifier_HateBERT.predict(fact_HateBERT))
    cf_off_hate.append(classifier_HateBERT.predict(cf_off_HateBERT))
f_hate = np.mean(f_hate,axis=0)
cf_off_hate = np.mean(cf_off_hate,axis=0)
# Out:
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5629 - accuracy: 0.6923
# Epoch 2/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5203 - accuracy: 0.7196
# Epoch 3/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4927 - accuracy: 0.7373
# Epoch 4/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4627 - accuracy: 0.7586
# Epoch 5/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4239 - accuracy: 0.7880
# Epoch 6/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.3861 - accuracy: 0.8071
# Epoch 7/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.3409 - accuracy: 0.8350
# Epoch 8/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.2914 - accuracy: 0.8628
# Epoch 9/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.2529 - accuracy: 0.8860
# Epoch 10/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.2153 - accuracy: 0.9052
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.6959
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5177 - accuracy: 0.7214
# Epoch 3/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4862 - accuracy: 0.7431
# Epoch 4/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4549 - accuracy: 0.7670
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4153 - accuracy: 0.7899
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3745 - accuracy: 0.8163
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3279 - accuracy: 0.8475
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2835 - accuracy: 0.8697
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2384 - accuracy: 0.8934
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2038 - accuracy: 0.9105
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5621 - accuracy: 0.6907
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5191 - accuracy: 0.7204
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4875 - accuracy: 0.7427
# Epoch 4/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4550 - accuracy: 0.7639
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4195 - accuracy: 0.7890
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3789 - accuracy: 0.8111
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3342 - accuracy: 0.8397
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2945 - accuracy: 0.8585
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2466 - accuracy: 0.8858
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2119 - accuracy: 0.9047
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5643 - accuracy: 0.6903
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5232 - accuracy: 0.7176
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4911 - accuracy: 0.7410
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4630 - accuracy: 0.7604
# Epoch 5/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.4264 - accuracy: 0.7815
# Epoch 6/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.3833 - accuracy: 0.8113
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3368 - accuracy: 0.8364
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2903 - accuracy: 0.8648
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2505 - accuracy: 0.8881
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2111 - accuracy: 0.9047
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5624 - accuracy: 0.6935
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5206 - accuracy: 0.7192
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4915 - accuracy: 0.7421
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4581 - accuracy: 0.7643
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4168 - accuracy: 0.7907
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3740 - accuracy: 0.8162
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3281 - accuracy: 0.8434
# Epoch 8/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.2869 - accuracy: 0.8619
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2416 - accuracy: 0.8884
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2082 - accuracy: 0.9071
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.6970
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5191 - accuracy: 0.7231
# Epoch 3/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4892 - accuracy: 0.7424
# Epoch 4/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4549 - accuracy: 0.7659
# Epoch 5/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.4174 - accuracy: 0.7915
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3736 - accuracy: 0.8177
# Epoch 7/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3290 - accuracy: 0.8428
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2833 - accuracy: 0.8685
# Epoch 9/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2404 - accuracy: 0.8892
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.5641 - accuracy: 0.6910
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5213 - accuracy: 0.7209
# Epoch 3/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.4937 - accuracy: 0.7402
# Epoch 4/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.4580 - accuracy: 0.7612
# Epoch 5/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.4222 - accuracy: 0.7869
# Epoch 6/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.3813 - accuracy: 0.8123
# Epoch 7/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.3355 - accuracy: 0.8363
# Epoch 8/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2866 - accuracy: 0.8619
# Epoch 9/10
# 526/526 [==============================] - 1s 3ms/step - loss: 0.2493 - accuracy: 0.8856
# Epoch 10/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.2161 - accuracy: 0.9031
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 1ms/step
# Epoch 1/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.5610 - accuracy: 0.6961
# Epoch 2/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.5200 - accuracy: 0.7175
# Epoch 3/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.4937 - accuracy: 0.7369
# Epoch 4/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.4603 - accuracy: 0.7598
# Epoch 5/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.4223 - accuracy: 0.7862
# Epoch 6/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.3817 - accuracy: 0.8100
# Epoch 7/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.3361 - accuracy: 0.8383
# Epoch 8/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.2937 - accuracy: 0.8623
# Epoch 9/10
# 526/526 [==============================] - 1s 1ms/step - loss: 0.2504 - accuracy: 0.8856
# Epoch 10/10
# 526/526 [==============================] - 1s 2ms/step - loss: 0.2096 - accuracy: 0.9065
# 98/98 [==============================] - 0s 1ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5620 - accuracy: 0.6881
# Epoch 2/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5199 - accuracy: 0.7204
# Epoch 3/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4930 - accuracy: 0.7380
# Epoch 4/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4596 - accuracy: 0.7610
# Epoch 5/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4232 - accuracy: 0.7828
# Epoch 6/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.3795 - accuracy: 0.8116
# Epoch 7/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.3411 - accuracy: 0.8344
# Epoch 8/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.2893 - accuracy: 0.8622
# Epoch 9/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.2572 - accuracy: 0.8789
# Epoch 10/10
# 526/526 [==============================] - 3s 5ms/step - loss: 0.2166 - accuracy: 0.9014
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5652 - accuracy: 0.6899
# Epoch 2/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.5192 - accuracy: 0.7183
# Epoch 3/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4920 - accuracy: 0.7400
# Epoch 4/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4551 - accuracy: 0.7670
# Epoch 5/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4154 - accuracy: 0.7869
# Epoch 6/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.3734 - accuracy: 0.8151
# Epoch 7/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.3263 - accuracy: 0.8425
# Epoch 8/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.2858 - accuracy: 0.8678
# Epoch 9/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.2396 - accuracy: 0.8920
# Epoch 10/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.1993 - accuracy: 0.9112
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5663 - accuracy: 0.6888
# Epoch 2/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5172 - accuracy: 0.7273
# Epoch 3/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4896 - accuracy: 0.7429
# Epoch 4/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4556 - accuracy: 0.7671
# Epoch 5/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.4156 - accuracy: 0.7942
# Epoch 6/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.3729 - accuracy: 0.8185
# Epoch 7/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.3301 - accuracy: 0.8408
# Epoch 8/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.2796 - accuracy: 0.8686
# Epoch 9/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.2425 - accuracy: 0.8874
# Epoch 10/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.2030 - accuracy: 0.9080
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step
# Epoch 1/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.5636 - accuracy: 0.6912
# Epoch 2/10
# 526/526 [==============================] - 2s 5ms/step - loss: 0.5192 - accuracy: 0.7194
# Epoch 3/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4895 - accuracy: 0.7414
# Epoch 4/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4581 - accuracy: 0.7675
# Epoch 5/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.4217 - accuracy: 0.7881
# Epoch 6/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.3806 - accuracy: 0.8143
# Epoch 7/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.3354 - accuracy: 0.8413
# Epoch 8/10
# 526/526 [==============================] - 2s 3ms/step - loss: 0.2911 - accuracy: 0.8673
# Epoch 9/10
# 526/526 [==============================] - 2s 4ms/step - loss: 0.2450 - accuracy: 0.8913
# Epoch 10/10
# 526/526 [==============================] - 3s 6ms/step - loss: 0.2085 - accuracy: 0.9087
# 98/98 [==============================] - 0s 2ms/step
# 489/489 [==============================] - 1s 2ms/step

# %%
i = 0
for j in range(0,len(cf_off),n_cf):
    samples[i].factual.hate_hateBERT = f_hate[i][0]
    samples[i].factual.hateBERT_pred = 1 if f_hate[i][0] > 0.5 else 0
    for k in range(n_cf):
        samples[i].cf_off[k].hate_hateBERT = cf_off_hate[j+k][0]
        samples[i].cf_off[k].hateBERT_pred = 1 if cf_off_hate[j+k][0] > 0.5 else 0
    i+=1

# %% [markdown]
# # Semantic embeddings

# %%
sem_trans = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %% [markdown]
# ## Factuals

# %%
sem_emb = sem_trans.encode(factuals)
for i in range(len(samples)):
    samples[i].factual.sem_emb = sem_emb[i]

# %% [markdown]
# ## Offense counterfactuals

# %%
sem_emb = sem_trans.encode(cf_off)
i = 0
for j in range(0,len(cf_off),n_cf):
    for k in range(n_cf):
        samples[i].cf_off[k].sem_emb = sem_emb[j+k]
    i+=1

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Factual vs. Counterfactual metrics

# %%
def cf_off_dist_sent(sample,k):
    #Euclidean distance considering the 3 sentiments
    return np.linalg.norm(sample.factual.sent - sample.cf_off[k].sent)

# %%
def cf_off_dist_off(sample,k,factual_off):
    if factual_off:
        dist = sample.factual.off - sample.cf_off[k].off 
    else:
        dist = sample.cf_off[k].off - sample.factual.off
    return dist

# %%
def cf_off_same_sent(sample,k):
    result = 1 if sample.factual.sent_pred == sample.cf_off[k].sent_pred else 0
    return result

# %%
def cf_off_distinct_off(sample,k,factual_off):
    if factual_off:
        result = 1 if sample.cf_off[k].off_pred==0 else 0 
    else:
        result = 1 if sample.cf_off[k].off_pred==1 else 0
    return result

# %%
def cf_off_off_improvement(sample,k,factual_off):
    if factual_off:
        result = 1 if sample.factual.off > sample.cf_off[k].off else 0
    else:
        result = 1 if sample.cf_off[k].off > sample.factual.off else 0
    return result

# %%
def sem_similarity(emb1,emb2):
    cos_sim = cosine_similarity([emb1],[emb2])[0][0]
    return cos_sim

# %%
for i in range(len(samples)):
    for k in range(n_cf):
        metrics_cf_off[i][k].dist_sent = cf_off_dist_sent(samples[i],k)
        metrics_cf_off[i][k].dist_off = cf_off_dist_off(samples[i],k,factual_off[i])
        metrics_cf_off[i][k].same_sent = cf_off_same_sent(samples[i],k)
        metrics_cf_off[i][k].distinct_off = cf_off_distinct_off(samples[i],k,factual_off[i])
        metrics_cf_off[i][k].off_improvement = cf_off_off_improvement(samples[i],k,factual_off[i])
        metrics_cf_off[i][k].sem_sim = sem_similarity(samples[i].factual.sem_emb,samples[i].cf_off[k].sem_emb)

# %%
# for i in [0,2]:
#     print("Factual")
#     samples[i].factual.print_info()
#     print()
#     print()
#     print("Offense Counterfactual")
#     samples[i].cf_off.print_info()
#     print()
#     metrics_cf_off[i].print_metrics()
#     print()
#     print()
#     print()

# %%
dists_off = []
dists_sent = []
same_sents = []
distinct_offs = []
off_imprs = []
sem_sims = []
for i in range(len(samples)):
    for k in range(n_cf):
        dists_off.append(metrics_cf_off[i][k].dist_off)
        dists_sent.append(metrics_cf_off[i][k].dist_sent)
        same_sents.append(metrics_cf_off[i][k].same_sent)
        distinct_offs.append(metrics_cf_off[i][k].distinct_off)
        off_imprs.append(metrics_cf_off[i][k].off_improvement)
        sem_sims.append(metrics_cf_off[i][k].sem_sim)

# %%
print("Average of offense distances:",np.mean(dists_off))
print("Average of sentiment distances:",np.mean(dists_sent))
print("Accuracy of same sentiment:",np.sum(same_sents)/len(cf_off))
print("Accuracy of distinct offense:",np.sum(distinct_offs)/len(cf_off))
print("Accuracy of offense improvement:",np.sum(off_imprs)/len(cf_off))
print("Average of semantic similarities:",np.mean(sem_sims))
# Out:
# Average of offense distances: 0.37973183
# Average of sentiment distances: 0.4024663
# Accuracy of same sentiment: 0.640997761432683
# Accuracy of distinct offense: 0.688135593220339
# Accuracy of offense improvement: 0.9394947233770387
# Average of semantic similarities: 0.71135855

# %% [markdown]
# ## ATE Hate|Offensivity

# %%
def ATE(hate,factual_offs):
    offs = []
    non_offs = []
    for i in range(len(hate)):
        if factual_offs[i]:
            offs.append(hate[i])
        else:
            non_offs.append(hate[i])
    return np.mean(offs)-np.mean(non_offs)

# %%
ATE_true = ATE(labels_factuals,factual_off)

PEACE_hate = []
for i in range(len(samples)):
    PEACE_hate.append(samples[i].factual.hate_peace)
ATE_PEACE = ATE(PEACE_hate,factual_off)

gen_hate = []
for i in range(len(samples)):
    gen_hate.append(samples[i].factual.hate_gen)
ATE_gen = ATE(gen_hate,factual_off)

hateBERT_hate = []
for i in range(len(samples)):
    hateBERT_hate.append(samples[i].factual.hate_hateBERT)
ATE_hateBERT = ATE(hateBERT_hate,factual_off)

# %%
print("ATE of the ground truth:",ATE_true)
print("ATE of PEACE:",ATE_PEACE)
print("ATE of the general module:",ATE_gen)
print("ATE of hateBERT:",ATE_hateBERT)
# Out:
# ATE of the ground truth: 0.2798126054217983
# ATE of PEACE: 0.31624407
# ATE of the general module: 0.27150553
# ATE of hateBERT: 0.27280977

# %% [markdown]
# ## ITE

# %%
ITE_peace = []
for i in range(len(samples)):
    if factual_off[i]:
        for k in range(n_cf):
            ITE_peace.append(samples[i].factual.hate_peace - samples[i].cf_off[k].hate_peace)
    else:
        for k in range(n_cf):
            ITE_peace.append(samples[i].cf_off[k].hate_peace - samples[i].factual.hate_peace)

np.save('outs/counterfactuals/ITE_peace.npy',np.array(ITE_peace))

# %%
ITE_peace = np.load('outs/counterfactuals/ITE_peace.npy')

# %%
print(np.mean(ITE_peace))
pd.Series(ITE_peace).hist()
# Out:
# 0.28862223
# <Axes: >
